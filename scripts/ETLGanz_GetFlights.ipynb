# %% [markdown]
# ## ETLGanz Get Flights
# ### 1. Objective
# To fetch flight data using the AeroDataBox (Rapid API), set up dataframes, and use SQL to store data for table queries. This notebook will focus on retrieving real-time flight information, processing the data, and storing it in a structured format for SQL Queries, further analysis as needed.

# %% [markdown]
# ### 2. Global Configuration

# %%
# Global Configuration
# Import necessary libraries

import pandas as pd
import numpy as np
import requests as req
import sqlalchemy as sa
import pymysql as pms
import re
import myconfig as cfg

from bs4 import BeautifulSoup
from datetime import datetime, date, timedelta
from pytz import timezone

import warnings

warnings.filterwarnings('ignore')

#Default path for data
# path = "..\Data\\"

# %% [markdown]
# ###  3. Third Party Data
# #####
# URLs for Airport, Flights details are below:
# ```markdown
# - AeroDataBox
# - [RapidAI](https://rapidapi.com/aedbx-aedbx/api/aerodatabox)
#
# ```

# %%
url1 ="https://aerodatabox.p.rapidapi.com/airports/search/location"

# %% [markdown]
# ### 4. Flights
# ### 4.1 Initial Checks
# ##### Parameters
# - **Site Response**: Check
# - **Lat, Long Definitions**: Defining the Latitudes, Longitudes for the chosen city
# - **Data Extraction Checks**: for city name, country, icao, iata, timezone data etc.

# %%
response1 = req.get(url1)
response1.status_code
# Out:
# 401

# %%
# Hash individually to check API Functionality
# Define Lat, Long for Berlin
latitudes = [52.5200]
longitudes = [13.4050]

# Define Lat, Long for Hamburg
# latitudes = [53.5511]
# longitudes = [9.9937]

# Define Lat, Long for Munich
# latitudes = [48.1351]
# longitudes = [11.5820]

# %%
querystring = {"lat":latitudes,"lon":longitudes,"radiusKm":"50","limit":"2","withFlightInfoOnly":"true"}

headers = {
	"X-RapidAPI-Key": "Input", # Insert your RapidAPI Key
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = req.get(url1, headers=headers, params=querystring)

response.json()
# Out:
# {'searchBy': {'lat': 52.52, 'lon': 13.405},
#  'count': 1,
#  'items': [{'icao': 'EDDB',
#    'iata': 'BER',
#    'name': 'Berlin Brandenburg',
#    'shortName': 'Brandenburg',
#    'municipalityName': 'Berlin',
#    'location': {'lat': 52.35139, 'lon': 13.493889},
#    'countryCode': 'DE',
#    'timeZone': 'Europe/Berlin'}]}

# %%
#Create dataframe with ICAO codes
def icao_airport_codes(latitudes, longitudes):

    list_for_df = []

    for index, value in enumerate(latitudes):

        querystring = {"lat":value,"lon":longitudes[index],"radiusKm":"50","limit":"3","withFlightInfoOnly":"true"}
        headers = {
            "X-RapidAPI-Key": "Input",  # Insert your RapidAPI Key
            "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
        }

        response = req.get(url1, headers=headers, params=querystring)
        list_for_df.append(pd.json_normalize(response.json()['items']))

    return pd.concat(list_for_df, ignore_index=True)

# coordinates for Berlin, 'Hamburg', 'Munich'
latitudes = [52.5200, 53.5511, 48.1351]
longitudes = [13.4050, 9.9937, 11.5820]

icao_airport_codes(latitudes, longitudes)
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
# 1  EDDH  HAM            Hamburg       Hamburg          Hamburg          DE
# 2  EDDM  MUC             Munich        Munich           Munich          DE
#
#         timeZone  location.lat  location.lon
# 0  Europe/Berlin      52.35139     13.493889
# 1  Europe/Berlin      53.63040      9.988229
# 2  Europe/Berlin      48.35380     11.786100

# %% [markdown]
# ### 4.2 Collect Data
# #### 4.2.1 Setup ICAO Dataframe

# %%
cities = ['Berlin', 'Hamburg', 'Munich']
icao_codes = ['EDDB', 'EDDH', 'EDDM']

icao_df = pd.DataFrame({
    'City': cities,
    'ICAO': icao_codes
})

icao_df
# Out:
#       City  ICAO
# 0   Berlin  EDDB
# 1  Hamburg  EDDH
# 2   Munich  EDDM

# %%
# City ID Column
icao_df['city_id'] = range(1, len(icao_df) + 1)
icao_df
# Out:
#       City  ICAO  city_id
# 0   Berlin  EDDB        1
# 1  Hamburg  EDDH        2
# 2   Munich  EDDM        3

# %% [markdown]
# #### 4.2.2 Check Flight Arrivals Citywise
# - **Sample Check**: For Berlin
# - **Arrival Times**: Sort and Order for Flight Arrivals
# - **Automated For Loop Citywise**: for icao, flight number, departure airport, flight status, aircraft info etc.

# %%
#Sample Check Berlin
url2 = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/EDDB/2024-11-28T11:00/2024-11-28T23:00"

querystring = {"withLeg":"false","withCancelled":"true","withCodeshared":"true","withLocation":"false"}

headers = {
	"X-RapidAPI-Key": "Input", # Insert your RapidAPI Key
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = req.get(url2, headers=headers, params=querystring)

arrival_information_berlin = response.json()
arrival_information_berlin
# Out:
# {'departures': [{'movement': {'airport': {'icao': 'GCTS',
#      'iata': 'TFS',
#      'name': 'Tenerife Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-11-28 10:00Z',
#      'local': '2024-11-28 11:00+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:00Z',
#      'local': '2024-11-28 11:00+01:00'},
#     'runwayTime': {'utc': '2024-11-28 10:19Z',
#      'local': '2024-11-28 11:19+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'A36',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5113',
#    'callSign': 'EJU19RC',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'GCTS',
#      'iata': 'TFS',
#      'name': 'Tenerife Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-11-28 10:00Z',
#      'local': '2024-11-28 11:00+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:00Z',
#      'local': '2024-11-28 11:00+01:00'},
#     'runwayTime': {'utc': '2024-11-28 10:19Z',
#      'local': '2024-11-28 11:19+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'A36',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5113',
#    'callSign': 'EJU19RC',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'movement': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-28 10:00Z',
#      'local': '2024-11-28 11:00+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:00Z',
#      'local': '2024-11-28 11:00+01:00'},
#     'runwayTime': {'utc': '2024-11-28 10:46Z',
#      'local': '2024-11-28 11:46+01:00'},
#     'terminal': '1',
#     'checkInDesk': '221-224',
#     'gate': 'C06',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 991',
#    'callSign': 'BAW91J',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-TTNF',
#     'modeS': '407536',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'movement': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-28 10:00Z',
#      'local': '2024-11-28 11:00+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:00Z',
#      'local': '2024-11-28 11:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'gate': 'B19',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1935',
#    'callSign': 'DLH4JW',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISD', 'modeS': '3C6664', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-11-28 10:20Z',
#      'local': '2024-11-28 11:20+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:20Z',
#      'local': '2024-11-28 11:20+01:00'},
#     'runwayTime': {'utc': '2024-11-28 10:33Z',
#      'local': '2024-11-28 11:33+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'gate': 'B17',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 226',
#    'callSign': 'AUA2BE',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LBJ', 'modeS': '440666', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'movement': {'airport': {'icao': 'EVRA',
#      'iata': 'RIX',
#      'name': 'Riga',
#      'timeZone': 'Europe/Riga'},
#     'scheduledTime': {'utc': '2024-11-28 10:20Z',
#      'local': '2024-11-28 11:20+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:20Z',
#      'local': '2024-11-28 11:20+01:00'},
#     'runwayTime': {'utc': '2024-11-28 10:35Z',
#      'local': '2024-11-28 11:35+01:00'},
#     'terminal': '2',
#     'checkInDesk': '158-165',
#     'gate': 'B34',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 2599',
#    'callSign': 'RYR151F',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QAF', 'modeS': '4D21EE', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'LTFM',
#      'iata': 'IST',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-11-28 10:25Z',
#      'local': '2024-11-28 11:25+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:25Z',
#      'local': '2024-11-28 11:25+01:00'},
#     'runwayTime': {'utc': '2024-11-28 10:37Z',
#      'local': '2024-11-28 11:37+01:00'},
#     'terminal': '1',
#     'checkInDesk': '912-916',
#     'gate': 'C07',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'TK 1722',
#    'callSign': 'THY8JM',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-LGL',
#     'modeS': '4BB0E7',
#     'model': 'Airbus A350-900'},
#    'airline': {'name': 'Turkish', 'iata': 'TK', 'icao': 'THY'}},
#   {'movement': {'airport': {'icao': 'EPWA',
#      'iata': 'WAW',
#      'name': 'Warsaw',
#      'timeZone': 'Europe/Warsaw'},
#     'scheduledTime': {'utc': '2024-11-28 10:25Z',
#      'local': '2024-11-28 11:25+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:25Z',
#      'local': '2024-11-28 11:25+01:00'},
#     'runwayTime': {'utc': '2024-11-28 10:31Z',
#      'local': '2024-11-28 11:31+01:00'},
#     'terminal': '1',
#     'checkInDesk': '121-122',
#     'gate': 'A31',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'LO 388',
#    'callSign': 'LOT3JA',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SP-LDI', 'modeS': '489789', 'model': 'Embraer 170'},
#    'airline': {'name': 'LOT - Polish', 'iata': 'LO', 'icao': 'LOT'}},
#   {'movement': {'airport': {'icao': 'HEMA',
#      'iata': 'RMF',
#      'name': 'Marsa Alam',
#      'timeZone': 'Africa/Cairo'},
#     'scheduledTime': {'utc': '2024-11-28 10:30Z',
#      'local': '2024-11-28 11:30+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:30Z',
#      'local': '2024-11-28 11:30+01:00'},
#     'runwayTime': {'utc': '2024-11-28 10:45Z',
#      'local': '2024-11-28 11:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'C12',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5363',
#    'callSign': 'EZY91GA',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'HEMA',
#      'iata': 'RMF',
#      'name': 'Marsa Alam',
#      'timeZone': 'Africa/Cairo'},
#     'scheduledTime': {'utc': '2024-11-28 10:30Z',
#      'local': '2024-11-28 11:30+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:30Z',
#      'local': '2024-11-28 11:30+01:00'},
#     'runwayTime': {'utc': '2024-11-28 10:45Z',
#      'local': '2024-11-28 11:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'C12',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5363',
#    'callSign': 'EJU91GA',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'movement': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik',
#      'timeZone': 'Atlantic/Reykjavik'},
#     'scheduledTime': {'utc': '2024-11-28 10:30Z',
#      'local': '2024-11-28 11:30+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:30Z',
#      'local': '2024-11-28 11:30+01:00'},
#     'terminal': '2',
#     'checkInDesk': '152-154',
#     'gate': 'B36',
#     'quality': ['Basic', 'Live']},
#    'number': 'OG 701',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TF-PPB',
#     'modeS': '4CC553',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Ghodawat Enterprises', 'iata': 'OG', 'icao': 'SDG'}},
#   {'movement': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik',
#      'timeZone': 'Atlantic/Reykjavik'},
#     'scheduledTime': {'utc': '2024-11-28 10:31Z',
#      'local': '2024-11-28 11:31+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:31Z',
#      'local': '2024-11-28 11:31+01:00'},
#     'runwayTime': {'utc': '2024-11-28 10:31Z',
#      'local': '2024-11-28 11:31+01:00'},
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FPY 85L',
#    'callSign': 'FPY85L',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TF-PPB',
#     'modeS': '4CC553',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'FPY'}},
#   {'movement': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-28 10:40Z',
#      'local': '2024-11-28 11:40+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:40Z',
#      'local': '2024-11-28 11:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'A37',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 5',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWH', 'modeS': '3C5EE8', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-28 10:40Z',
#      'local': '2024-11-28 11:40+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:40Z',
#      'local': '2024-11-28 11:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'gate': 'B10',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 185',
#    'callSign': 'DLH185',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIQS', 'modeS': '3C6633', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm',
#      'timeZone': 'Europe/Stockholm'},
#     'scheduledTime': {'utc': '2024-11-28 10:45Z',
#      'local': '2024-11-28 11:45+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:45Z',
#      'local': '2024-11-28 11:45+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:03Z',
#      'local': '2024-11-28 12:03+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-516',
#     'gate': 'B07',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'SK 2678',
#    'callSign': 'SAS2678',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SE-ROT', 'modeS': '4AC9F4', 'model': 'Airbus A320'},
#    'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}},
#   {'movement': {'airport': {'icao': 'EGNT',
#      'iata': 'NCL',
#      'name': 'Newcastle upon Tyne',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-28 10:45Z',
#      'local': '2024-11-28 11:45+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:45Z',
#      'local': '2024-11-28 11:45+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:00Z',
#      'local': '2024-11-28 12:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '211-212',
#     'gate': 'C17',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'LS 1960',
#    'callSign': 'EXS76HJ',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-JZHA', 'modeS': '406CAB', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Jet2', 'iata': 'LS', 'icao': 'EXS'}},
#   {'movement': {'airport': {'icao': 'EGLC',
#      'iata': 'LCY',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-28 10:45Z',
#      'local': '2024-11-28 11:45+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:45Z',
#      'local': '2024-11-28 11:45+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:31Z',
#      'local': '2024-11-28 12:31+01:00'},
#     'terminal': '1',
#     'checkInDesk': '221-224',
#     'gate': 'D06',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8492',
#    'callSign': 'CFE34E',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-LCAG', 'modeS': '4079D2', 'model': 'Embraer 190'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'movement': {'airport': {'icao': 'LEMD',
#      'iata': 'MAD',
#      'name': 'Madrid',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-28 10:40Z',
#      'local': '2024-11-28 11:40+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:50Z',
#      'local': '2024-11-28 11:50+01:00'},
#     'terminal': '1',
#     'checkInDesk': '114-116',
#     'gate': 'A34',
#     'quality': ['Basic', 'Live']},
#    'number': 'IB 1802',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-NST',
#     'modeS': '347247',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Iberia', 'iata': 'IB', 'icao': 'IBE'}},
#   {'movement': {'airport': {'icao': 'LEMD',
#      'iata': 'MAD',
#      'name': 'Madrid',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-28 10:40Z',
#      'local': '2024-11-28 11:40+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:50Z',
#      'local': '2024-11-28 11:50+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:06Z',
#      'local': '2024-11-28 12:06+01:00'},
#     'terminal': '1',
#     'checkInDesk': '114-116',
#     'gate': 'A34',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'I2 1802',
#    'callSign': 'IBS18FR',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-NST',
#     'modeS': '347247',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Iberia Express', 'iata': 'I2', 'icao': 'IBS'}},
#   {'movement': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2024-11-28 10:50Z',
#      'local': '2024-11-28 11:50+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:50Z',
#      'local': '2024-11-28 11:50+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:18Z',
#      'local': '2024-11-28 12:18+01:00'},
#     'terminal': '1',
#     'checkInDesk': '811-816',
#     'gate': 'A30',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1776',
#    'callSign': 'KLM1776',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BGF', 'modeS': '48455D', 'model': 'Boeing 737'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'movement': {'airport': {'icao': 'LGAV',
#      'iata': 'ATH',
#      'name': 'Athens',
#      'timeZone': 'Europe/Athens'},
#     'scheduledTime': {'utc': '2024-11-28 10:40Z',
#      'local': '2024-11-28 11:40+01:00'},
#     'revisedTime': {'utc': '2024-11-28 10:52Z',
#      'local': '2024-11-28 11:52+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:16Z',
#      'local': '2024-11-28 12:16+01:00'},
#     'terminal': '1',
#     'checkInDesk': '011-013',
#     'gate': 'A35',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'A3 821',
#    'callSign': 'AEE2WD',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SX-NET',
#     'modeS': '46B8B4',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}},
#   {'movement': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels',
#      'timeZone': 'Europe/Brussels'},
#     'scheduledTime': {'utc': '2024-11-28 10:55Z',
#      'local': '2024-11-28 11:55+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:06Z',
#      'local': '2024-11-28 12:06+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:09Z',
#      'local': '2024-11-28 12:09+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'gate': 'B19',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2582',
#    'callSign': 'BEL4NK',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OO-SNE', 'modeS': '44CDC5', 'model': 'Airbus A320'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'movement': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-28 11:15Z',
#      'local': '2024-11-28 12:15+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:15Z',
#      'local': '2024-11-28 12:15+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:38Z',
#      'local': '2024-11-28 12:38+01:00'},
#     'terminal': '2',
#     'checkInDesk': '158-165',
#     'gate': 'B36',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 148',
#    'callSign': 'RYR47MB',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-HAT', 'modeS': '4CA92B', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'name': 'Unknown'},
#     'scheduledTime': {'utc': '2024-11-28 11:16Z',
#      'local': '2024-11-28 12:16+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:16Z',
#      'local': '2024-11-28 12:16+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:16Z',
#      'local': '2024-11-28 12:16+01:00'},
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'DFORH',
#    'callSign': 'DFORH',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-FORH', 'modeS': '3D7009', 'model': 'Pilatus PC-12'},
#    'airline': {'name': 'Unknown/Private owner'}},
#   {'movement': {'airport': {'icao': 'LFPG',
#      'iata': 'CDG',
#      'name': 'Paris',
#      'timeZone': 'Europe/Paris'},
#     'scheduledTime': {'utc': '2024-11-28 11:20Z',
#      'local': '2024-11-28 12:20+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:20Z',
#      'local': '2024-11-28 12:20+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:57Z',
#      'local': '2024-11-28 12:57+01:00'},
#     'terminal': '1',
#     'checkInDesk': '811-816',
#     'gate': 'A32',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1735',
#    'callSign': 'AFR1735',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-GTAY', 'modeS': '394C18', 'model': 'Airbus A321'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'movement': {'airport': {'icao': 'HEGN',
#      'iata': 'HRG',
#      'name': 'Hurghada',
#      'timeZone': 'Africa/Cairo'},
#     'scheduledTime': {'utc': '2024-11-28 11:20Z',
#      'local': '2024-11-28 12:20+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:20Z',
#      'local': '2024-11-28 12:20+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:39Z',
#      'local': '2024-11-28 12:39+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'C02',
#     'runway': '07R',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8982',
#    'callSign': 'EWG40X',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENA',
#     'modeS': '3C55C1',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'ENBR',
#      'iata': 'BGO',
#      'name': 'Bergen',
#      'timeZone': 'Europe/Oslo'},
#     'scheduledTime': {'utc': '2024-11-28 11:25Z',
#      'local': '2024-11-28 12:25+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:25Z',
#      'local': '2024-11-28 12:25+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:43Z',
#      'local': '2024-11-28 12:43+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-516',
#     'gate': 'B32',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'DY 1161',
#    'callSign': 'NOZ61C',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SE-RPJ', 'modeS': '4ACA0A', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#   {'movement': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen',
#      'timeZone': 'Europe/Copenhagen'},
#     'scheduledTime': {'utc': '2024-11-28 11:30Z',
#      'local': '2024-11-28 12:30+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:30Z',
#      'local': '2024-11-28 12:30+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-516',
#     'gate': 'B38',
#     'quality': ['Basic', 'Live']},
#    'number': 'D8 3303',
#    'callSign': 'NSZ3303',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SE-RRE', 'modeS': '4ACA45', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Sweden', 'iata': 'D8', 'icao': 'NSZ'}},
#   {'movement': {'airport': {'icao': 'ENTC',
#      'iata': 'TOS',
#      'name': 'Tromsø',
#      'timeZone': 'Europe/Oslo'},
#     'scheduledTime': {'utc': '2024-11-28 11:35Z',
#      'local': '2024-11-28 12:35+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:35Z',
#      'local': '2024-11-28 12:35+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:50Z',
#      'local': '2024-11-28 12:50+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-516',
#     'gate': 'B30',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'DY 1125',
#    'callSign': 'NOZ1125',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'LN-NII', 'modeS': '47945C', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Norwegian Air Shuttle', 'iata': 'DY', 'icao': 'NOZ'}},
#   {'movement': {'airport': {'icao': 'LTAI',
#      'iata': 'AYT',
#      'name': 'Antalya',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-11-28 11:15Z',
#      'local': '2024-11-28 12:15+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:40Z',
#      'local': '2024-11-28 12:40+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:00Z',
#      'local': '2024-11-28 13:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '721-726',
#     'gate': 'D03',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'PC 5008',
#    'callSign': 'PGT5008',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-NBZ',
#     'modeS': '4BB85A',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#   {'movement': {'airport': {'icao': 'EDDK',
#      'iata': 'CGN',
#      'name': 'Cologne',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-28 11:40Z',
#      'local': '2024-11-28 12:40+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:40Z',
#      'local': '2024-11-28 12:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'A07',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 7',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWB', 'modeS': '3C5EE2', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-28 11:40Z',
#      'local': '2024-11-28 12:40+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:40Z',
#      'local': '2024-11-28 12:40+01:00'},
#     'runwayTime': {'utc': '2024-11-28 11:53Z',
#      'local': '2024-11-28 12:53+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'gate': 'B17',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 187',
#    'callSign': 'DLH6JF',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZY',
#     'modeS': '3C6759',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-28 11:45Z',
#      'local': '2024-11-28 12:45+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:45Z',
#      'local': '2024-11-28 12:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'A36',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2003',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWO', 'modeS': '3C5EEF', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-28 11:55Z',
#      'local': '2024-11-28 12:55+01:00'},
#     'revisedTime': {'utc': '2024-11-28 11:55Z',
#      'local': '2024-11-28 12:55+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:26Z',
#      'local': '2024-11-28 13:26+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'gate': 'B07',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 2207',
#    'callSign': 'DLH9TW',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISB', 'modeS': '3C6662', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'EGPF',
#      'iata': 'GLA',
#      'name': 'Glasgow',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-28 12:00Z',
#      'local': '2024-11-28 13:00+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:00Z',
#      'local': '2024-11-28 13:00+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:23Z',
#      'local': '2024-11-28 13:23+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'C13',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5313',
#    'callSign': 'EJU83TL',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBF', 'modeS': '440CF8', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'EGPF',
#      'iata': 'GLA',
#      'name': 'Glasgow',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-28 12:00Z',
#      'local': '2024-11-28 13:00+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:00Z',
#      'local': '2024-11-28 13:00+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:23Z',
#      'local': '2024-11-28 13:23+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'C13',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5313',
#    'callSign': 'EJU83TL',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBF', 'modeS': '440CF8', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'movement': {'airport': {'icao': 'EGSS',
#      'iata': 'STN',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-28 12:05Z',
#      'local': '2024-11-28 13:05+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:05Z',
#      'local': '2024-11-28 13:05+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:37Z',
#      'local': '2024-11-28 14:37+01:00'},
#     'terminal': '2',
#     'checkInDesk': '158-165',
#     'gate': 'B42',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 146',
#    'callSign': 'RYR8LE',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-DHG', 'modeS': '4CA263', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'name': 'Unknown'},
#     'scheduledTime': {'utc': '2024-11-28 12:08Z',
#      'local': '2024-11-28 13:08+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:08Z',
#      'local': '2024-11-28 13:08+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:08Z',
#      'local': '2024-11-28 13:08+01:00'},
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'NJE 414B',
#    'callSign': 'NJE385A',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'CS-GLB',
#     'modeS': '491D82',
#     'model': 'Bombardier Global Express'},
#    'airline': {'name': 'NetJets Europe', 'icao': 'NJE'}},
#   {'movement': {'airport': {'icao': 'HEGN',
#      'iata': 'HRG',
#      'name': 'Hurghada',
#      'timeZone': 'Africa/Cairo'},
#     'scheduledTime': {'utc': '2024-11-28 12:10Z',
#      'local': '2024-11-28 13:10+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:10Z',
#      'local': '2024-11-28 13:10+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:48Z',
#      'local': '2024-11-28 13:48+01:00'},
#     'terminal': '1',
#     'checkInDesk': '924-926',
#     'gate': 'D06',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'SM 2961',
#    'callSign': 'MSC2961',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SU-BVK',
#     'modeS': '01025C',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Air Cairo', 'iata': 'SM', 'icao': 'MSC'}},
#   {'movement': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik',
#      'timeZone': 'Atlantic/Reykjavik'},
#     'scheduledTime': {'utc': '2024-11-28 11:55Z',
#      'local': '2024-11-28 12:55+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:10Z',
#      'local': '2024-11-28 13:10+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:17Z',
#      'local': '2024-11-28 13:17+01:00'},
#     'terminal': '1',
#     'checkInDesk': '714-716',
#     'gate': 'A10',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'FI 529',
#    'callSign': 'ICE15M',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TF-ICE', 'modeS': '4CC50E', 'model': 'Boeing 737'},
#    'airline': {'name': 'Icelandair', 'iata': 'FI', 'icao': 'ICE'}},
#   {'movement': {'airport': {'name': 'Unknown'},
#     'scheduledTime': {'utc': '2024-11-28 12:13Z',
#      'local': '2024-11-28 13:13+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:13Z',
#      'local': '2024-11-28 13:13+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:13Z',
#      'local': '2024-11-28 13:13+01:00'},
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'VJT 407',
#    'callSign': 'VJT407',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VCP',
#     'modeS': '4D2374',
#     'model': 'Bombardier Challenger 350'},
#    'airline': {'name': 'VistaJet', 'icao': 'VJT'}},
#   {'movement': {'airport': {'icao': 'LEMG',
#      'iata': 'AGP',
#      'name': 'Málaga',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-28 11:50Z',
#      'local': '2024-11-28 12:50+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:15Z',
#      'local': '2024-11-28 13:15+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:25Z',
#      'local': '2024-11-28 13:25+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'A33',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5105',
#    'callSign': 'EJU71EZ',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDU', 'modeS': '440DAF', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'LEMG',
#      'iata': 'AGP',
#      'name': 'Málaga',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-28 11:50Z',
#      'local': '2024-11-28 12:50+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:15Z',
#      'local': '2024-11-28 13:15+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:25Z',
#      'local': '2024-11-28 13:25+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'A33',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5105',
#    'callSign': 'EJU71EZ',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDU', 'modeS': '440DAF', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'movement': {'airport': {'icao': 'EFHK',
#      'iata': 'HEL',
#      'name': 'Helsinki',
#      'timeZone': 'Europe/Helsinki'},
#     'scheduledTime': {'utc': '2024-11-28 12:00Z',
#      'local': '2024-11-28 13:00+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:15Z',
#      'local': '2024-11-28 13:15+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:42Z',
#      'local': '2024-11-28 13:42+01:00'},
#     'terminal': '1',
#     'checkInDesk': '521-523',
#     'gate': 'A31',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1434',
#    'callSign': 'FIN3YX',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LZL',
#     'modeS': '461FA1',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'movement': {'airport': {'icao': 'LATI',
#      'iata': 'TIA',
#      'name': 'Tirana',
#      'timeZone': 'Europe/Tirane'},
#     'scheduledTime': {'utc': '2024-11-28 12:05Z',
#      'local': '2024-11-28 13:05+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:16Z',
#      'local': '2024-11-28 13:16+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:42Z',
#      'local': '2024-11-28 13:42+01:00'},
#     'terminal': '2',
#     'checkInDesk': '154-157',
#     'gate': 'B40',
#     'quality': ['Basic', 'Live']},
#    'number': 'W4 5106',
#    'callSign': 'WMT977',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HA-LXN', 'modeS': '471F6F', 'model': 'Airbus A321'},
#    'airline': {'name': 'Aero Services Executive',
#     'iata': 'W4',
#     'icao': 'WMT'}},
#   {'movement': {'airport': {'icao': 'LTAI',
#      'iata': 'AYT',
#      'name': 'Antalya',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-11-28 12:25Z',
#      'local': '2024-11-28 13:25+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:25Z',
#      'local': '2024-11-28 13:25+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:59Z',
#      'local': '2024-11-28 13:59+01:00'},
#     'terminal': '1',
#     'checkInDesk': '024-026',
#     'gate': 'C15',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'XQ 161',
#    'callSign': 'SXS1CM',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-SME', 'modeS': '4BCDA5', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#   {'movement': {'airport': {'icao': 'GCRR',
#      'iata': 'ACE',
#      'name': 'Lanzarote Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-11-28 12:25Z',
#      'local': '2024-11-28 13:25+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:25Z',
#      'local': '2024-11-28 13:25+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:50Z',
#      'local': '2024-11-28 13:50+01:00'},
#     'terminal': '2',
#     'checkInDesk': '158-165',
#     'gate': 'B32',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3366',
#    'callSign': 'RYR87VK',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VVS',
#     'modeS': '4D2504',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'LTFJ',
#      'iata': 'SAW',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-11-28 11:00Z',
#      'local': '2024-11-28 12:00+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:30Z',
#      'local': '2024-11-28 13:30+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:46Z',
#      'local': '2024-11-28 13:46+01:00'},
#     'terminal': '1',
#     'checkInDesk': '721-726',
#     'gate': 'D02',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'PC 978',
#    'callSign': 'PGT5FR',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-RDN',
#     'modeS': '4BC88E',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#   {'movement': {'airport': {'icao': 'LHBP',
#      'iata': 'BUD',
#      'name': 'Budapest',
#      'timeZone': 'Europe/Budapest'},
#     'scheduledTime': {'utc': '2024-11-28 12:10Z',
#      'local': '2024-11-28 13:10+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:30Z',
#      'local': '2024-11-28 13:30+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:44Z',
#      'local': '2024-11-28 13:44+01:00'},
#     'terminal': '2',
#     'checkInDesk': '154-157',
#     'gate': 'B34',
#     'quality': ['Basic', 'Live']},
#    'number': 'W6 2316',
#    'callSign': 'WZZ7LF',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HA-LZY',
#     'modeS': '471FAE',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Wizz Air', 'iata': 'W6', 'icao': 'WZZ'}},
#   {'movement': {'airport': {'icao': 'LTFJ',
#      'iata': 'SAW',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-11-28 12:40Z',
#      'local': '2024-11-28 13:40+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:40Z',
#      'local': '2024-11-28 13:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '621-623',
#     'gate': 'D10',
#     'quality': ['Basic', 'Live']},
#    'number': 'VF 58',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-GEM', 'modeS': '4D24A7', 'model': 'Boeing 737'},
#    'airline': {'name': 'Ajet', 'iata': 'VF', 'icao': 'VLU'}},
#   {'movement': {'airport': {'icao': 'LOWW',
#      'iata': 'VIE',
#      'name': 'Vienna',
#      'timeZone': 'Europe/Vienna'},
#     'scheduledTime': {'utc': '2024-11-28 12:15Z',
#      'local': '2024-11-28 13:15+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:40Z',
#      'local': '2024-11-28 13:40+01:00'},
#     'runwayTime': {'utc': '2024-11-28 12:55Z',
#      'local': '2024-11-28 13:55+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'gate': 'B17',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'OS 228',
#    'callSign': 'AUA8BE',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LXD', 'modeS': '44029F', 'model': 'Airbus A320'},
#    'airline': {'name': 'Austrian', 'iata': 'OS', 'icao': 'AUA'}},
#   {'movement': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-28 12:40Z',
#      'local': '2024-11-28 13:40+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:40Z',
#      'local': '2024-11-28 13:40+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:01Z',
#      'local': '2024-11-28 14:01+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'gate': 'B19',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 189',
#    'callSign': 'DLH189',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AINN',
#     'modeS': '3C65CE',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'LTBJ',
#      'iata': 'ADB',
#      'name': 'İzmir',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-11-28 12:55Z',
#      'local': '2024-11-28 13:55+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:55Z',
#      'local': '2024-11-28 13:55+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:12Z',
#      'local': '2024-11-28 14:12+01:00'},
#     'terminal': '1',
#     'checkInDesk': '021-023',
#     'gate': 'C02',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'XQ 947',
#    'callSign': 'SXS1VR',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-SMJ',
#     'modeS': '4BCDAA',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Sun Express', 'iata': 'XQ', 'icao': 'SXS'}},
#   {'movement': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo',
#      'timeZone': 'Asia/Jerusalem'},
#     'scheduledTime': {'utc': '2024-11-28 12:20Z',
#      'local': '2024-11-28 13:20+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:55Z',
#      'local': '2024-11-28 13:55+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:24Z',
#      'local': '2024-11-28 14:24+01:00'},
#     'terminal': '1',
#     'checkInDesk': '824-826',
#     'gate': 'C21',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': '6H 254',
#    'callSign': 'ISR254',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '4X-ABT', 'modeS': '738288', 'model': 'Airbus A320'},
#    'airline': {'name': 'Israir', 'iata': '6H', 'icao': 'ISR'}},
#   {'movement': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-28 12:55Z',
#      'local': '2024-11-28 13:55+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:55Z',
#      'local': '2024-11-28 13:55+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:07Z',
#      'local': '2024-11-28 14:07+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'A38',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5121',
#    'callSign': 'EJU47NF',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICR', 'modeS': '440469', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'LEPA',
#      'iata': 'PMI',
#      'name': 'Palma De Mallorca',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-28 12:55Z',
#      'local': '2024-11-28 13:55+01:00'},
#     'revisedTime': {'utc': '2024-11-28 12:55Z',
#      'local': '2024-11-28 13:55+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:07Z',
#      'local': '2024-11-28 14:07+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'A38',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5121',
#    'callSign': 'EJU47NF',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICR', 'modeS': '440469', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'movement': {'airport': {'icao': 'EGLL',
#      'iata': 'LHR',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-28 13:00Z',
#      'local': '2024-11-28 14:00+01:00'},
#     'revisedTime': {'utc': '2024-11-28 13:00Z',
#      'local': '2024-11-28 14:00+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:43Z',
#      'local': '2024-11-28 14:43+01:00'},
#     'terminal': '1',
#     'checkInDesk': '221-225',
#     'gate': 'C06',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 983',
#    'callSign': 'BAW983',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-TTNC',
#     'modeS': '407462',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'movement': {'airport': {'icao': 'LTFJ',
#      'iata': 'SAW',
#      'name': 'Istanbul',
#      'timeZone': 'Europe/Istanbul'},
#     'scheduledTime': {'utc': '2024-11-28 13:08Z',
#      'local': '2024-11-28 14:08+01:00'},
#     'revisedTime': {'utc': '2024-11-28 13:08Z',
#      'local': '2024-11-28 14:08+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:10Z',
#      'local': '2024-11-28 14:10+01:00'},
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'TKJ 9GZ',
#    'callSign': 'TKJ9GZ',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-GEM', 'modeS': '4D24A7', 'model': 'Boeing 737'},
#    'airline': {'name': 'TKJ'}},
#   {'movement': {'airport': {'icao': 'EGLC',
#      'iata': 'LCY',
#      'name': 'London',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-28 13:10Z',
#      'local': '2024-11-28 14:10+01:00'},
#     'revisedTime': {'utc': '2024-11-28 13:10Z',
#      'local': '2024-11-28 14:10+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:46Z',
#      'local': '2024-11-28 14:46+01:00'},
#     'terminal': '1',
#     'checkInDesk': '221-225',
#     'gate': 'C17',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 7026',
#    'callSign': 'BAW7026',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-LCYK', 'modeS': '406230', 'model': 'Embraer 190'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'movement': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-28 13:20Z',
#      'local': '2024-11-28 14:20+01:00'},
#     'revisedTime': {'utc': '2024-11-28 13:20Z',
#      'local': '2024-11-28 14:20+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:29Z',
#      'local': '2024-11-28 14:29+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'A37',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5187',
#    'callSign': 'EJU91BR',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDX', 'modeS': '440DB0', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-28 13:20Z',
#      'local': '2024-11-28 14:20+01:00'},
#     'revisedTime': {'utc': '2024-11-28 13:20Z',
#      'local': '2024-11-28 14:20+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:29Z',
#      'local': '2024-11-28 14:29+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'A37',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5187',
#    'callSign': 'EJU91BR',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDX', 'modeS': '440DB0', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'movement': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen',
#      'timeZone': 'Europe/Copenhagen'},
#     'scheduledTime': {'utc': '2024-11-28 13:20Z',
#      'local': '2024-11-28 14:20+01:00'},
#     'revisedTime': {'utc': '2024-11-28 13:20Z',
#      'local': '2024-11-28 14:20+01:00'},
#     'runwayTime': {'utc': '2024-11-28 13:28Z',
#      'local': '2024-11-28 14:28+01:00'},
#     'terminal': '1',
#     'checkInDesk': '611-616',
#     'gate': 'A34',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5263',
#    'callSign': 'EZY5263',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LKM', 'modeS': '440625', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen',
#      'timeZone': 'Europe/Copenhagen'},
#     'scheduledTime': {'utc': '2024-11-28 13:20Z',
#      'local': '2024-11-28 14:20+01:00'},
# ...
#     'scheduledTime': {'utc': '2024-11-28 20:45Z',
#      'local': '2024-11-28 21:45+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:02Z',
#      'local': '2024-11-28 22:02+01:00'},
#     'terminal': '1',
#     'gate': 'N02',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8495',
#    'callSign': 'BAW8495',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-LCAH', 'modeS': '4079D3', 'model': 'Embraer 190'},
#    'airline': {'name': 'British', 'iata': 'BA', 'icao': 'BAW'}},
#   {'movement': {'airport': {'icao': 'OMDB',
#      'iata': 'DXB',
#      'name': 'Dubai',
#      'timeZone': 'Asia/Dubai'},
#     'scheduledTime': {'utc': '2024-11-28 21:00Z',
#      'local': '2024-11-28 22:00+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:07Z',
#      'local': '2024-11-28 22:07+01:00'},
#     'runwayTime': {'utc': '2024-11-28 21:07Z',
#      'local': '2024-11-28 22:07+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'A1',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 1151',
#    'callSign': 'EWG5D',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'movement': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2024-11-28 21:25Z',
#      'local': '2024-11-28 22:25+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:11Z',
#      'local': '2024-11-28 22:11+01:00'},
#     'runwayTime': {'utc': '2024-11-28 21:11Z',
#      'local': '2024-11-28 22:11+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B3',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5286',
#    'callSign': 'EJU37LH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IZL', 'modeS': '4400B7', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam',
#      'timeZone': 'Europe/Amsterdam'},
#     'scheduledTime': {'utc': '2024-11-28 21:25Z',
#      'local': '2024-11-28 22:25+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:11Z',
#      'local': '2024-11-28 22:11+01:00'},
#     'runwayTime': {'utc': '2024-11-28 21:11Z',
#      'local': '2024-11-28 22:11+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B3',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5286',
#    'callSign': 'EJU37LH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IZL', 'modeS': '4400B7', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'movement': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels',
#      'timeZone': 'Europe/Brussels'},
#     'scheduledTime': {'utc': '2024-11-28 21:20Z',
#      'local': '2024-11-28 22:20+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:14Z',
#      'local': '2024-11-28 22:14+01:00'},
#     'runwayTime': {'utc': '2024-11-28 21:14Z',
#      'local': '2024-11-28 22:14+01:00'},
#     'terminal': '1',
#     'gate': 'B03',
#     'baggageBelt': 'B1',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2591',
#    'callSign': 'BEL1ZK',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OO-TCQ', 'modeS': '44D071', 'model': 'Airbus A320'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'movement': {'airport': {'icao': 'LSGG',
#      'iata': 'GVA',
#      'name': 'Geneva',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-28 21:35Z',
#      'local': '2024-11-28 22:35+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:18Z',
#      'local': '2024-11-28 22:18+01:00'},
#     'runwayTime': {'utc': '2024-11-28 21:18Z',
#      'local': '2024-11-28 22:18+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A4',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5186',
#    'callSign': 'EJU16TR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDX', 'modeS': '440DB0', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'LSGG',
#      'iata': 'GVA',
#      'name': 'Geneva',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-28 21:35Z',
#      'local': '2024-11-28 22:35+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:18Z',
#      'local': '2024-11-28 22:18+01:00'},
#     'runwayTime': {'utc': '2024-11-28 21:18Z',
#      'local': '2024-11-28 22:18+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A4',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5186',
#    'callSign': 'EJU16TR',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDX', 'modeS': '440DB0', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'movement': {'airport': {'icao': 'HEMA',
#      'iata': 'RMF',
#      'name': 'Marsa Alam',
#      'timeZone': 'Africa/Cairo'},
#     'scheduledTime': {'utc': '2024-11-28 21:30Z',
#      'local': '2024-11-28 22:30+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:20Z',
#      'local': '2024-11-28 22:20+01:00'},
#     'terminal': '1',
#     'gate': 'N02',
#     'baggageBelt': 'A4',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5364',
#    'callSign': 'EJU43GH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'HEMA',
#      'iata': 'RMF',
#      'name': 'Marsa Alam',
#      'timeZone': 'Africa/Cairo'},
#     'scheduledTime': {'utc': '2024-11-28 21:30Z',
#      'local': '2024-11-28 22:30+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:20Z',
#      'local': '2024-11-28 22:20+01:00'},
#     'terminal': '1',
#     'gate': 'N02',
#     'baggageBelt': 'A4',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5364',
#    'callSign': 'EJU43GH',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBS', 'modeS': '440D10', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'movement': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-28 21:25Z',
#      'local': '2024-11-28 22:25+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:24Z',
#      'local': '2024-11-28 22:24+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 202',
#    'callSign': 'DLH202',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIRF', 'modeS': '3C6646', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'LSZH',
#      'iata': 'ZRH',
#      'name': 'Zurich',
#      'timeZone': 'Europe/Zurich'},
#     'scheduledTime': {'utc': '2024-11-28 21:20Z',
#      'local': '2024-11-28 22:20+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:25Z',
#      'local': '2024-11-28 22:25+01:00'},
#     'terminal': '1',
#     'gate': 'B02',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 962',
#    'callSign': 'SWR558F',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-IJP', 'modeS': '4B1619', 'model': 'Airbus A320'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'movement': {'airport': {'icao': 'LPPT',
#      'iata': 'LIS',
#      'name': 'Lisbon',
#      'timeZone': 'Europe/Lisbon'},
#     'scheduledTime': {'utc': '2024-11-28 21:25Z',
#      'local': '2024-11-28 22:25+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:28Z',
#      'local': '2024-11-28 22:28+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1143',
#    'callSign': 'RYR38GP',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VUH', 'modeS': '4D2347', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'GCTS',
#      'iata': 'TFS',
#      'name': 'Tenerife Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-11-28 21:25Z',
#      'local': '2024-11-28 22:25+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:30Z',
#      'local': '2024-11-28 22:30+01:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5114',
#    'callSign': 'EJU86CT',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'GCTS',
#      'iata': 'TFS',
#      'name': 'Tenerife Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-11-28 21:25Z',
#      'local': '2024-11-28 22:25+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:30Z',
#      'local': '2024-11-28 22:30+01:00'},
#     'terminal': '1',
#     'gate': 'A35',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5114',
#    'callSign': 'EJU86CT',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IZN', 'modeS': '440CA9', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'movement': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona',
#      'timeZone': 'Europe/Madrid'},
#     'scheduledTime': {'utc': '2024-11-28 21:40Z',
#      'local': '2024-11-28 22:40+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:32Z',
#      'local': '2024-11-28 22:32+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 133',
#    'callSign': 'RYR4QG',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QAF', 'modeS': '4D21EE', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'GCLP',
#      'iata': 'LPA',
#      'name': 'Gran Canaria Island',
#      'timeZone': 'Atlantic/Canary'},
#     'scheduledTime': {'utc': '2024-11-28 20:45Z',
#      'local': '2024-11-28 21:45+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:34Z',
#      'local': '2024-11-28 22:34+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C2',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 2501',
#    'callSign': 'RYR9RW',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-VUE', 'modeS': '4D2303', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'LIRF',
#      'iata': 'FCO',
#      'name': 'Rome',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-28 21:35Z',
#      'local': '2024-11-28 22:35+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:36Z',
#      'local': '2024-11-28 22:36+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5080',
#    'callSign': 'EJU64EB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDO', 'modeS': '4400F3', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'movement': {'airport': {'icao': 'LIRF',
#      'iata': 'FCO',
#      'name': 'Rome',
#      'timeZone': 'Europe/Rome'},
#     'scheduledTime': {'utc': '2024-11-28 21:35Z',
#      'local': '2024-11-28 22:35+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:36Z',
#      'local': '2024-11-28 22:36+01:00'},
#     'terminal': '1',
#     'gate': 'B06',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5080',
#    'callSign': 'EJU64EB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDO', 'modeS': '4400F3', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'movement': {'airport': {'icao': 'LPPT',
#      'iata': 'LIS',
#      'name': 'Lisbon',
#      'timeZone': 'Europe/Lisbon'},
#     'scheduledTime': {'utc': '2024-11-28 21:35Z',
#      'local': '2024-11-28 22:35+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:41Z',
#      'local': '2024-11-28 22:41+01:00'},
#     'runwayTime': {'utc': '2024-11-28 21:41Z',
#      'local': '2024-11-28 22:41+01:00'},
#     'terminal': '1',
#     'gate': 'A20',
#     'baggageBelt': 'A3',
#     'runway': '25L',
#     'quality': ['Basic', 'Live']},
#    'number': 'TP 534',
#    'callSign': 'TAP534',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'CS-TVA',
#     'modeS': '4952C1',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'TAP Air Portugal', 'iata': 'TP', 'icao': 'TAP'}},
#   {'movement': {'airport': {'icao': 'EDDM',
#      'iata': 'MUC',
#      'name': 'Munich',
#      'timeZone': 'Europe/Berlin'},
#     'scheduledTime': {'utc': '2024-11-28 21:40Z',
#      'local': '2024-11-28 22:40+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:43Z',
#      'local': '2024-11-28 22:43+01:00'},
#     'runwayTime': {'utc': '2024-11-28 21:42Z',
#      'local': '2024-11-28 22:42+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B4',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1958',
#    'callSign': 'DLH4N',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIUE',
#     'modeS': '3C66A5',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'movement': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester',
#      'timeZone': 'Europe/London'},
#     'scheduledTime': {'utc': '2024-11-28 21:55Z',
#      'local': '2024-11-28 22:55+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:43Z',
#      'local': '2024-11-28 22:43+01:00'},
#     'runwayTime': {'utc': '2024-11-28 21:43Z',
#      'local': '2024-11-28 22:43+01:00'},
#     'terminal': '2',
#     'gate': 'Z38',
#     'baggageBelt': 'C1',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1145',
#    'callSign': 'RYR82YX',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-IGI',
#     'modeS': '4CADBB',
#     'model': 'Boeing 737 MAX 8'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'movement': {'airport': {'icao': 'HEGN',
#      'iata': 'HRG',
#      'name': 'Hurghada',
#      'timeZone': 'Africa/Cairo'},
#     'scheduledTime': {'utc': '2024-11-28 22:10Z',
#      'local': '2024-11-28 23:10+01:00'},
#     'revisedTime': {'utc': '2024-11-28 21:56Z',
#      'local': '2024-11-28 22:56+01:00'},
#     'terminal': '1',
#     'gate': 'N02',
#     'baggageBelt': 'A1',
#     'runway': '25R',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8983',
#    'callSign': 'EWG8983',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENA',
#     'modeS': '3C55C1',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}}]}

# %%
# Sort out & Order Flights
# Hash and run one at a time, as needed

pd.json_normalize(arrival_information_berlin['arrivals'])
arrival_information_berlin['arrivals'][0]
arrival_information_berlin['departures'][0]

#Flight Number
arrival_information_berlin['arrivals'][0]['number']

#Status
arrival_information_berlin['arrivals'][0]['status']

#Departure Airport
arrival_information_berlin['arrivals'][0]['movement']['airport']['name']

#Revised arrival time
arrival_information_berlin['arrivals'][0]['movement']['revisedTime']['local']

#Scheduled arrival time
arrival_information_berlin['arrivals'][0]['movement']['scheduledTime']['local']

#Aircraft
arrival_information_berlin['arrivals'][0]['aircraft']['model']
# Out:
# 'Airbus A320 NEO'

# %%
# Data Exploration Cities 'Berlin', 'Hamburg', 'Munich'
# ICAO Codes ['EDDB', 'EDDH', 'EDDM']
list_of_airports = ['EDDB']

# %%
current_datetime = datetime.now()
time_from = current_datetime.strftime("%Y-%m-%d %H:%M")
time_from
# Out:
# '2024-12-03 16:00'

# %%
time_to = current_datetime + timedelta(hours=12)
time_to = time_to.strftime("%Y-%m-%d %H:%M")
time_to
# Out:
# '2024-12-04 04:00'

# %% [markdown]
# Code-On:
# Using a `for` loop with `try` and `except KeyError` is useful when iterating over a collection (like a list or dictionary) where some keys might not exist. This approach allows the program to handle missing keys gracefully without crashing, ensuring that the rest of the loop continues to execute.
#
# Here's a brief example in Python:
#
# ```python
# data = [{'name': 'Alice'}, {'name': 'Bob'}, {'age': 30}]
#
# for item in data:
#     try:
#         print(item['name'])
#     except KeyError:
#         print('Name key is missing')
# ```
#
# In this example, the `try` block attempts to access the 'name' key, and the `except KeyError` block handles cases where the 'name' key is not present, preventing the program from crashing.

# %%
# For Loop for Data Extraction

flight_data = []

for airport in list_of_airports:
    
    url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{airport}/{time_from}/{time_to}"
    querystring = {"withLeg":"false","withCancelled":"true","withCodeshared":"true","withLocation":"false"}
    headers = {
        "X-RapidAPI-Key": "Input",  # Insert your RapidAPI Key
        "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"}

    response = req.get(url, headers=headers, params=querystring)
    flight_json = response.json()

    for entry in flight_json['arrivals']:
        try:
            revised_time = entry['movement']['revisedTime']['local']
        except KeyError:
            revised_time = 'N/A' 

        flight_data.append({
            "ICAO": airport,
            "Flight Number": entry['number'],
            "Departure Airport": entry['movement']['airport']['name'],
            "Status": entry['status'],
            "Scheduled arrival date_time": entry['movement']['scheduledTime']['local'],
            "Revised arrival date_time": revised_time
        })

flight_df = pd.DataFrame(flight_data)
flight_df
# Out:
#      ICAO Flight Number Departure Airport    Status  \
# 0    EDDB       LH 1942            Munich  Expected
# 1    EDDB        TP 532            Lisbon  Expected
# 2    EDDB        PC 985          Istanbul  Expected
# 3    EDDB        6H 253     Tel Aviv Yafo  Expected
# 4    EDDB        OS 231            Vienna  Expected
# ..    ...           ...               ...       ...
# 112  EDDB       FR 2419   Tenerife Island  Expected
# 113  EDDB       U2 8631            London  Expected
# 114  EDDB       EC 8631            London  Expected
# 115  EDDB       I2 1809            Madrid  Expected
# 116  EDDB       IB 1809            Madrid  Expected
#
#     Scheduled arrival date_time Revised arrival date_time
# 0        2024-12-03 16:00+01:00    2024-12-03 16:00+01:00
# 1        2024-12-03 16:10+01:00    2024-12-03 16:00+01:00
# 2        2024-12-03 16:15+01:00    2024-12-03 16:09+01:00
# 3        2024-12-03 16:35+01:00    2024-12-03 16:14+01:00
# 4        2024-12-03 16:20+01:00    2024-12-03 16:20+01:00
# ..                          ...                       ...
# 112      2024-12-03 23:00+01:00    2024-12-03 23:00+01:00
# 113      2024-12-03 23:00+01:00    2024-12-03 23:00+01:00
# 114      2024-12-03 23:00+01:00    2024-12-03 23:00+01:00
# 115      2024-12-03 23:10+01:00    2024-12-03 23:10+01:00
# 116      2024-12-03 23:10+01:00    2024-12-03 23:10+01:00
#
# [117 rows x 6 columns]

# %% [markdown]
# #### 4.2.3 Collect Data
# Automating a function to collect data with a flist as below

# %%
# Part 1: Dive Deeper in 3 parts
list_of_airports = ['EDDB', 'EDDH', 'EDDM']

# %%
def get_flight_data(list_of_airports):
    
    flight_data = []
    
    today = datetime.now().astimezone(timezone('Europe/Berlin')).date()
    tomorrow = (today + timedelta(days=1))

    for airport in list_of_airports:
        
        times = [["00:00","11:59"],["12:00","23:59"]]

        for time in times:
            
            url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{airport}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"
            querystring = {"withLeg":"false","withCancelled":"true","withCodeshared":"true","withLocation":"false"}
            headers = {
                "X-RapidAPI-Key": "Input",  # Insert your RapidAPI Key
                "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"}

            response = req.get(url, headers=headers, params=querystring)
            flight_json = response.json()

            for entry in flight_json['arrivals']:
                try:
                    revised_time = entry['movement']['revisedTime']['local']
                except KeyError:
                    revised_time = 'N/A' 
                    
                try:
                    aircraft_model = entry['aircraft']['model']
                except KeyError:
                    aircraft_model = 'N/A'

                flight_data.append({
                    "ICAO": airport,
                    "Flight_Number": entry['number'],
                    "Departure_Airport": entry['movement']['airport']['name'],
                    "Flight_Status": entry['status'],
                    "Scheduled_arrival_date": entry['movement']['scheduledTime']['local'],
                    "Revised_arrival_date": revised_time,
                    "Aircraft": aircraft_model,
                    "Data_retrieved_on": today
                })

    flight_df = pd.DataFrame(flight_data)
    return flight_df

# %%
flight_df = get_flight_data(list_of_airports)
flight_df
# Out:
#      ICAO Flight_Number Departure_Airport Flight_Status  \
# 0    EDDB        FI 518         Reykjavik      Expected
# 1    EDDB        HU 489           Beijing      Expected
# 2    EDDB         QR 79              Doha      Expected
# 3    EDDB       EW 8001         Stuttgart      Expected
# 4    EDDB          EW 2           Cologne      Expected
# ..    ...           ...               ...           ...
# 776  EDDM        LO 355            Warsaw      Expected
# 777  EDDM        IB 747            Madrid      Expected
# 778  EDDM        BA 958            London      Expected
# 779  EDDM       LH 2483            London      Expected
# 780  EDDM        TP 556            Lisbon      Expected
#
#      Scheduled_arrival_date    Revised_arrival_date  \
# 0    2024-12-04 06:15+01:00                     N/A
# 1    2024-12-04 06:40+01:00  2024-12-04 06:40+01:00
# 2    2024-12-04 06:55+01:00  2024-12-04 06:55+01:00
# 3    2024-12-04 07:35+01:00  2024-12-04 07:35+01:00
# 4    2024-12-04 07:40+01:00  2024-12-04 07:40+01:00
# ..                      ...                     ...
# 776  2024-12-04 22:25+01:00  2024-12-04 22:25+01:00
# 777  2024-12-04 22:40+01:00  2024-12-04 22:40+01:00
# 778  2024-12-04 22:45+01:00  2024-12-04 22:45+01:00
# 779  2024-12-04 23:05+01:00  2024-12-04 23:05+01:00
# 780  2024-12-04 23:10+01:00  2024-12-04 23:10+01:00
#
#                         Aircraft Data_retrieved_on
# 0                     Boeing 737        2024-12-03
# 1                   Boeing 787-9        2024-12-03
# 2                   Boeing 787-9        2024-12-03
# 3                    Airbus A319        2024-12-03
# 4    Airbus A320-200 (sharklets)        2024-12-03
# ..                           ...               ...
# 776                   Boeing 737        2024-12-03
# 777                  Airbus A320        2024-12-03
# 778                  Airbus A320        2024-12-03
# 779              Airbus A320 NEO        2024-12-03
# 780              Airbus A320 NEO        2024-12-03
#
# [781 rows x 8 columns]

# %%
# Part 2: Cleaning the Dataframe
def clean_flight_data(flight_df):
    
    flight_df['Scheduled_arrival_date'] = pd.to_datetime(flight_df['Scheduled_arrival_date'])
    flight_df['Data_retrieved_on'] = pd.to_datetime(flight_df['Data_retrieved_on'])
    flight_df['Revised_arrival_date'] = pd.to_datetime(flight_df['Revised_arrival_date'], errors='coerce')
    
    return flight_df

# %%
# Part 3: Setting up Final Cleaned Data
flight_df_final = clean_flight_data(flight_df)
flight_df_final
# Out:
#      ICAO Flight_Number Departure_Airport Flight_Status  \
# 0    EDDB        FI 518         Reykjavik      Expected
# 1    EDDB        HU 489           Beijing      Expected
# 2    EDDB         QR 79              Doha      Expected
# 3    EDDB       EW 8001         Stuttgart      Expected
# 4    EDDB          EW 2           Cologne      Expected
# ..    ...           ...               ...           ...
# 776  EDDM        LO 355            Warsaw      Expected
# 777  EDDM        IB 747            Madrid      Expected
# 778  EDDM        BA 958            London      Expected
# 779  EDDM       LH 2483            London      Expected
# 780  EDDM        TP 556            Lisbon      Expected
#
#        Scheduled_arrival_date      Revised_arrival_date  \
# 0   2024-12-04 06:15:00+01:00                       NaT
# 1   2024-12-04 06:40:00+01:00 2024-12-04 06:40:00+01:00
# 2   2024-12-04 06:55:00+01:00 2024-12-04 06:55:00+01:00
# 3   2024-12-04 07:35:00+01:00 2024-12-04 07:35:00+01:00
# 4   2024-12-04 07:40:00+01:00 2024-12-04 07:40:00+01:00
# ..                        ...                       ...
# 776 2024-12-04 22:25:00+01:00 2024-12-04 22:25:00+01:00
# 777 2024-12-04 22:40:00+01:00 2024-12-04 22:40:00+01:00
# 778 2024-12-04 22:45:00+01:00 2024-12-04 22:45:00+01:00
# 779 2024-12-04 23:05:00+01:00 2024-12-04 23:05:00+01:00
# 780 2024-12-04 23:10:00+01:00 2024-12-04 23:10:00+01:00
#
#                         Aircraft Data_retrieved_on
# 0                     Boeing 737        2024-12-03
# 1                   Boeing 787-9        2024-12-03
# 2                   Boeing 787-9        2024-12-03
# 3                    Airbus A319        2024-12-03
# 4    Airbus A320-200 (sharklets)        2024-12-03
# ..                           ...               ...
# 776                   Boeing 737        2024-12-03
# 777                  Airbus A320        2024-12-03
# 778                  Airbus A320        2024-12-03
# 779              Airbus A320 NEO        2024-12-03
# 780              Airbus A320 NEO        2024-12-03
#
# [781 rows x 8 columns]

# %%
flight_df_sql=flight_df_final.copy()
flight_df_sql
# Out:
#      ICAO Flight_Number Departure_Airport Flight_Status  \
# 0    EDDB        FI 518         Reykjavik      Expected
# 1    EDDB        HU 489           Beijing      Expected
# 2    EDDB         QR 79              Doha      Expected
# 3    EDDB       EW 8001         Stuttgart      Expected
# 4    EDDB          EW 2           Cologne      Expected
# ..    ...           ...               ...           ...
# 776  EDDM        LO 355            Warsaw      Expected
# 777  EDDM        IB 747            Madrid      Expected
# 778  EDDM        BA 958            London      Expected
# 779  EDDM       LH 2483            London      Expected
# 780  EDDM        TP 556            Lisbon      Expected
#
#        Scheduled_arrival_date      Revised_arrival_date  \
# 0   2024-12-04 06:15:00+01:00                       NaT
# 1   2024-12-04 06:40:00+01:00 2024-12-04 06:40:00+01:00
# 2   2024-12-04 06:55:00+01:00 2024-12-04 06:55:00+01:00
# 3   2024-12-04 07:35:00+01:00 2024-12-04 07:35:00+01:00
# 4   2024-12-04 07:40:00+01:00 2024-12-04 07:40:00+01:00
# ..                        ...                       ...
# 776 2024-12-04 22:25:00+01:00 2024-12-04 22:25:00+01:00
# 777 2024-12-04 22:40:00+01:00 2024-12-04 22:40:00+01:00
# 778 2024-12-04 22:45:00+01:00 2024-12-04 22:45:00+01:00
# 779 2024-12-04 23:05:00+01:00 2024-12-04 23:05:00+01:00
# 780 2024-12-04 23:10:00+01:00 2024-12-04 23:10:00+01:00
#
#                         Aircraft Data_retrieved_on
# 0                     Boeing 737        2024-12-03
# 1                   Boeing 787-9        2024-12-03
# 2                   Boeing 787-9        2024-12-03
# 3                    Airbus A319        2024-12-03
# 4    Airbus A320-200 (sharklets)        2024-12-03
# ..                           ...               ...
# 776                   Boeing 737        2024-12-03
# 777                  Airbus A320        2024-12-03
# 778                  Airbus A320        2024-12-03
# 779              Airbus A320 NEO        2024-12-03
# 780              Airbus A320 NEO        2024-12-03
#
# [781 rows x 8 columns]

# %% [markdown]
# ### 4.3 Flight Data
# #### 4.3.1 Config & Dataframe
# You may also use the config file provided in the Github Repository to run this (**Option 1**)

# %%
# Option 1: Using the Alternate Method to Get Config Data
from safe import safe
safe.get('SERVER_HOST')
safe.get('SERVER_USER')
safe.get('SERVER_PASSWORD')
safe.get('SERVER_PORT')
safe.get('FLIGHT_API_KEY')

# %%
# Option 2: Without safe.py file
schema = "Input"  # Insert your schema name
host = "Input"  # Insert your host
user = "Input"       # Insert your user  
password = 'Input' # Insert your password
port = Input     # Insert your port

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %% [markdown]
# ### 4.2 Flight Dataframe Creation
# #### 4.2.2 SQL Push-Pull Request

# %%
flight_df_sql.to_sql('flight_data',
              if_exists='append',
              con=connection_string,
              index=False)
# Out:
# 781

# %% [markdown]
# ### 5. Retrospection
# ##### 1. Flights Data
# - **Challenges**:
#     - **API Rate Limiting**: Handling the rate limits imposed by the AeroDataBox API, which required careful timing and batching of requests to avoid hitting the limit.
#     - **Data Consistency**: Ensuring consistent data retrieval, especially when dealing with missing keys or values in the API response, which required robust error handling.
#     - **Timezone Management**: Managing timezones correctly, particularly when converting and comparing datetime values from different sources to ensure accurate scheduling and arrival times.
#
# - **Highlights**:
#     - **Automated Data Collection**: Successfully automated the process of collecting flight data for multiple airports, which streamlined the data retrieval process and reduced manual effort.
#     - **Data Cleaning and Transformation**: Implemented effective data cleaning and transformation functions to ensure the data was in a suitable format for analysis and storage in the SQL database.
#     - **SQL Integration**: Seamlessly integrated the cleaned flight data into a MySQL database, enabling efficient storage and retrieval for further analysis and reporting.
